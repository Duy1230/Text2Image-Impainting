# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !git clone https://github.com/IDEA-Research/GroundingDINO.git
# Out:
# Cloning into 'GroundingDINO'...
# remote: Enumerating objects: 463, done.
# remote: Counting objects: 100% (240/240), done.
# remote: Compressing objects: 100% (104/104), done.
# remote: Total 463 (delta 175), reused 136 (delta 136), pack-reused 223 (from 1)
# Receiving objects: 100% (463/463), 12.87 MiB | 20.12 MiB/s, done.
# Resolving deltas: 100% (241/241), done.

# %%
# !cd GroundingDINO && pip install -e .
# Out:
# Obtaining file:///kaggle/working/GroundingDINO
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 15.9 MB/s eta 0:00:00
# ...
#   Running setup.py develop for groundingdino
# ...

# %%
import sys
sys.path.append('/kaggle/working/GroundingDINO')

# %%
# %pip install huggingface_hub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install git+https://github.com/huggingface/diffusers.git
# Out:
# ...
#   Cloning https://github.com/huggingface/diffusers.git to /tmp/pip-req-build-d69abr0q
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers.git /tmp/pip-req-build-d69abr0q
#   Resolved https://github.com/huggingface/diffusers.git to commit 07860f991639f35f4b5a152676bd4d590c3e589e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for diffusers: filename=diffusers-0.33.0.dev0-py3-none-any.whl size=3287476 sha256=cb3cbb300439b0c10144cfaa80c76a0c502d7a6e9411d520a27c52fad06913a7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-eey_ww3y/wheels/4d/b7/a8/6f9549ceec5daad78675b857ac57d697c387062506520a7b50
# Successfully built diffusers
# ...
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.31.0
#     Uninstalling diffusers-0.31.0:
#       Successfully uninstalled diffusers-0.31.0
# ...

# %%
# %pip install fastapi nest-asyncio pyngrok uvicorn python-multipart
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 5.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !ngrok config add-authtoken 2nWCWyomomJ1lyKhW8JYbJpKT1S_2cBhY2ssSnyuDVzbtP7Eu
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
 import sys
# !{sys.executable} -m pip install opencv-python matplotlib
# !{sys.executable} -m pip install 'git+https://github.com/facebookresearch/segment-anything-2.git'
# Out:
# ...
#   Cloning https://github.com/facebookresearch/segment-anything-2.git to /tmp/pip-req-build-xd2r0wls
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/segment-anything-2.git /tmp/pip-req-build-xd2r0wls
#   Resolved https://github.com/facebookresearch/segment-anything-2.git to commit 2b90b9f5ceec907a1c18123530e92e794ad901a4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 5.5 MB/s eta 0:00:00
# ...
#   Created wheel for SAM-2: filename=SAM_2-1.0-cp310-cp310-linux_x86_64.whl size=522803 sha256=3f576ffb5e6ec2ea4aba27622af8622e9987408ca1faca23ac1fb4589d1cae51
# ...

# %%
import shutil
import os

def clear_dir():
    os.chdir('/kaggle/working')
    folder_path = "/kaggle/working/Text2Image-Impainting"

    # Method 1: Using shutil.rmtree() (recommended for non-empty directories)
    shutil.rmtree(folder_path)

# %%
# !git clone -b develop https://github.com/Duy1230/Text2Image-Impainting.git
# !cd Text2Image-Impainting/backend/weights/groundingdino && wget https://github.com/IDEA-Research/GroundingDINO/releases/download/v0.1.0-alpha/groundingdino_swint_ogc.pth
os.chdir('Text2Image-Impainting/backend')
# Out:
# Cloning into 'Text2Image-Impainting'...
# remote: Enumerating objects: 363, done.
# remote: Counting objects: 100% (363/363), done.
# remote: Compressing objects: 100% (210/210), done.
# remote: Total 363 (delta 175), reused 307 (delta 122), pack-reused 0 (from 0)
# Receiving objects: 100% (363/363), 213.95 KiB | 5.78 MiB/s, done.
# Resolving deltas: 100% (175/175), done.
# --2025-01-26 09:16:16--  https://github.com/IDEA-Research/GroundingDINO/releases/download/v0.1.0-alpha/groundingdino_swint_ogc.pth
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !pip install wget
# !pip install safetensors
# %cd weights
# !mkdir -p diffusion_checkpoints
# %cd diffusion_checkpoints
# Download a safetensor from civitai, this link changes often, you may find more here https://civitai.com/models
import wget 
wget.download('https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/764940/juggernautXI.UXFd.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22juggernautXL_juggXIByRundiffusion.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250126/us-east-1/s3/aws4_request&X-Amz-Date=20250126T083640Z&X-Amz-SignedHeaders=host&X-Amz-Signature=f973e16a948d4dcb96ecba8f12ff699df2395d0debe5609f5c84eb89f2d7ab60', out="checkpoint.safetensors")
# %cd ../..
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=a38e5dabf97398bf5819dab97842d620e06fdb0704cb71dac05b6685cc7fb5f6
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
# /kaggle/working/Text2Image-Impainting/backend/weights
# /kaggle/working/Text2Image-Impainting/backend/weights/diffusion_checkpoints
# /kaggle/working/Text2Image-Impainting/backend

# %%
from pyngrok import ngrok

# Set up ngrok tunnel to the FastAPI server
public_url = ngrok.connect(8000)
print(f"Public URL: {public_url}")
# Out:
# Public URL: NgrokTunnel: "https://6a33-35-227-17-2.ngrok-free.app" -> "http://localhost:8000"

# %%
from fastapi import FastAPI
import uvicorn

# Import the FastAPI app
from main import app

# Function to run the FastAPI server
# !uvicorn main:app #--reload
# Out:
# sam2_hiera_tiny.pt:   0%|          | 0.00/156M [00:00<?, ?B/s]
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# ...
# final text_encoder_type: bert-base-uncased
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# ...
# config.json:   0%|          | 0.00/1.31k [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# Fetching 17 files:   0%|          | 0/17 [00:00<?, ?it/s]
# text_encoder_2/config.json:   0%|          | 0.00/575 [00:00<?, ?B/s]
# ...

# %%
clear_dir()

# %%
ngrok.kill()
